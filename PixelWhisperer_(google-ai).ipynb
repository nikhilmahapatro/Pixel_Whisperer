# %%
# pip install -q -U google-generativeai

import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyCjnMkwXykKi9zztTsWDCZ-4Z76NlOAknY")

model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17")

try:
    response = model.generate_content("Difference between rugby vs soccer")
    print(response.text)  # Instead of print(response)
except Exception as e:
    print("Error:", e)
# Out:
# Okay, here's a breakdown of the main differences between Rugby (specifically Rugby Union, the most common comparison to soccer) and Soccer (Football):
#
# | Feature          | Rugby Union                                     | Soccer (Football)                                 |
# | :--------------- | :---------------------------------------------- | :------------------------------------------------ |
# | **Objective**    | Score points by carrying the ball over the opponent's try line (a Try), then kicking conversions, penalties, or drop goals through the H-shaped posts. | Score goals by kicking or heading the ball into the opponent's net. |
# | **Ball Handling**| Primarily hands (carrying, passing backward). Kicking is also used. | Primarily feet, head, and body. Hand use is strictly limited (except for the goalkeeper). |
# | **Passing**      | Passing *by hand* must be **backward** or sideways. Kicking can be forward. | Passing *by foot* can be in any direction (forward, backward, sideways). |
# | **Players**      | 15 players per team on the field.             | 11 players per team on the field (including the goalkeeper). |
# | **Scoring**      | Try (5 points), Conversion (2 points after a try), Penalty Goal (3 points), Drop Goal (3 points). | Goal (1 point).                                   |
# | **Tackling / Contact** | Full contact sport. Players *tackle* the ball carrier to bring them to the ground. Rucks and Mauls involve physical contests over the ball. Much higher level of tolerated contact. | Limited contact. Players challenge for the ball primarily with their feet or shoulder-to-shoulder. Tackles involve trying to take the ball away from the opponent's feet. Fouls are called for tripping, pushing, or excessive contact. |
# | **Offside Rule** | Situational offside lines, often related to the position of the ball in scrums, rucks, mauls, or kicks. | A player is offside if they are in an offside position (usually ahead of the ball and the second-to-last defender when the ball is played to them) and become involved in the play. |
# | **Restarts**     | Kick-offs, Scrums (for minor infringements like forward passes or knock-ons), Lineouts (when the ball goes out of bounds), Free Kicks, Penalty Kicks. | Kick-offs, Throw-ins (when the ball goes out of bounds), Corner Kicks, Goal Kicks, Free Kicks, Penalty Kicks. |
# | **The Ball**     | Oval-shaped (prolate spheroid).                 | Spherical.                                        |
# | **The Pitch**    | Rectangular. Has try lines and in-goal areas at each end, as well as the main playing field. H-shaped goalposts are on the try lines. | Rectangular. Has goal lines at each end, penalty areas, a center circle. Rectangular goal frame with a net at each end. |
# | **Game Duration**| 80 minutes (two 40-minute halves), plus some stoppage time. | 90 minutes (two 45-minute halves), plus significant stoppage time for injuries, substitutions, etc. |
# | **Goalposts**    | H-shaped posts with a crossbar, located on the try line (or goal line). Used for scoring conversions, penalties, and drop goals. | Rectangular frame with a net, located on the goal line. Used for scoring goals. |
# | **Equipment**    | Players often wear mouthguards (highly recommended/sometimes mandatory), scrum caps, and shoulder pads in addition to boots, shorts, and jerseys. | Players wear shin pads (mandatory), boots, shorts, and jerseys. |
#
# In essence:
#
# *   **Rugby** is a game built around carrying, tackling, and contesting possession with the hands (passing backward) and feet, with scoring primarily through tries (carrying the ball over the line).
# *   **Soccer** is a game built around kicking and controlling the ball with the feet (passing in any direction), with scoring only by getting the ball into the net.
#
# Both require teamwork, skill, and strategy, but the fundamental mechanics of ball handling, movement, and contact are vastly different.

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace('.', '*')
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it

# %%
model = genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-06-17')

# %%
import PIL.Image

# %%
img1 = PIL.Image.open(r"C:\Users\nikhi\PycharmProjects\NARESH_IT\PROJECTS_NARESH_IT\Pixel_Whisperer_-GenAI\random_Img1.jpg")
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=391x550>

# %%
img2 = PIL.Image.open(r"C:\Users\nikhi\PycharmProjects\NARESH_IT\PROJECTS_NARESH_IT\Pixel_Whisperer_-GenAI\random_Img2.jpg")
img2
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=600x600>

# %%
response1 = model.generate_content(img1)
to_markdown(response1.text)  # Works in any terminal
# Out:
# >A sloth is shown in the center of the image, riding a slice of pizza through outer space* The sloth is emitting rainbow-colored laser beams from its eyes* Several burritos and tacos are scattered around the sloth and pizza slice* The background is a starry, galaxy-like pattern in shades of pink and purple*

# %%
response2 = model.generate_content(img2)
to_markdown(response2.text)  # Works in any terminal
# Out:
# >The image is a square with a colorful, intricate design* It features a symmetrical pattern with elements resembling leaves, flowers, and swirling lines* The dominant colors are warm tones such as red, orange, yellow, and brown, interspersed with blues, greens, and black accents* The design has a bohemian or folk art aesthetic, with a slightly aged or vintage feel* The overall impression is one of a decorative textile, such as a scarf or tapestry, or perhaps a digital illustration designed to evoke such a feel* The intricate detail and bright colors suggest a celebration of nature and a vibrant, lively mood*
